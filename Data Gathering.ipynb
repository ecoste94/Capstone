# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
from pprint import pprint
# %matplotlib inline

# %%
import json
import time
import tqdm

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 10000

# %% [markdown]
# Acquiring the data was in itself the biggest challenege posed by this project. This is because Activison changed the default data privacy settings to private. As a result, accessing the in-game data of other players has now become impossible, unless players manually change their privacy settings to public on the Activision website. This means that classic APIs such as tracker.gg or RapidAPI have lost a lot in terms of practicality without a list of public gamer ids, which I am yet to find.
#
# After initial research, Alexandre le Corre's Warzone API available on RapidAPI was the best option. However, it has two limitations. The first is that without access to a list of 'public' gamer ids the only available data for download is 'Leaderboard'. Unfortunately, this data is not very exciting containing 16 variables such as: Prestige, XP, Time Played, Wins, Losses, Killstreaks, etc. The second problem is that being a Freemium API, I was limited to 500 rows of data a day.
#
# I also came across an API developed by iShot, which was available on Postman. Even though the privacy constraint still existed this API has access to a wealth of public data (79 columns) such as: Missions Completed, Player Stats, Weapons etc. as long as one can provide match ids. By chance, browsing through the API's discussion on Discord I found a pdf file posted by Caedrius with a list of 1000 match ids (each match contains data on c.150 players) in which he played. Even though I was ideally looking for a list of random ids belonging to a range of players, this was the best I could find and would provide more than enough data to explore my question.
#
# So, once I managed to convert the pdf into a JSON, I adapted the Postman API from the platform so that I could collect the data from all the match ids in one go. This is the exercise that has been carried out in this section.

# %%
df_match = pd.read_json("matchids.json", orient ='columns', dtype = {"matchId": object})

# %%
# This is the dataframe of the pdf of match ids belonging to Caedrius
df_match.head()
# Out:
#   platform title           timestamp              type               matchId  \
# 0   battle    mw 2021-01-04 22:18:36  6552125305277136   6562602456312274390
# 1   battle    mw 2021-01-04 22:07:30  6552125305277136  13368494592966401607
# 2   battle    mw 2021-01-04 15:51:12  3465102547637332   2284449555397668477
# 3   battle    mw 2021-01-01 16:13:47  3465102547637332  11831952490139849563
# 4   battle    mw 2021-01-01 15:40:38  3465102547637332    807350072882036898
#
#                 map
# 0  3227376819739457
# 1  3227376819739457
# 2  3227376819739457
# 3  3227376819739457
# 4  3227376819739457

# %%
# extracting the match ids into an iterable list
matchIds = df_match['matchId'].tolist()

# %%
# Adjusted Postman API so that all the data associated to each match id can be downloaded in a single collected effort

matches = []

for matchId in matchIds:
    url = 'https://www.callofduty.com/api/papi-client/crm/cod/v2/title/mw/platform/battle/fullMatch/wz/{}/it'.format(matchId)
    r_ = requests.get(url=url)
#     time.sleep(random.randint(2, 5))
    matches.append(r_)

# %%
matches.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8fbbfdbad843> in <module>
# ----> 1 matches
#
# NameError: name 'matches' is not defined

# %%
######DON'T LOAD#####

# %%
# each match is then converted into a readable dictionary format
duels = []
for match in matches:
    duel = json.loads(match.text)
    duels.append(duel)

# %%
duels[1]
# Out:
# {'status': 'success',
#  'data': {'allPlayers': [{'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 1.0,
#      'medalXp': 10.0,
#      'objectiveTeamWiped': 1.0,
#      'matchXp': 7069.0,
#      'scoreXp': 3200.0,
#      'wallBangs': 0.0,
#      'score': 2900.0,
#      'totalXp': 10279.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 30.0,
#      'scorePerMinute': 242.3398328690808,
#      'distanceTraveled': 211795.75,
#      'teamSurvivalTime': 656688.0,
#      'deaths': 2.0,
#      'kdRatio': 0.5,
#      'objectiveBrDownEnemyCircle1': 1.0,
#      'objectiveBrMissionPickupTablet': 1.0,
#      'bonusXp': 0.0,
#      'objectiveBrKioskBuy': 1.0,
#      'gulagDeaths': 1.0,
#      'timePlayed': 718.0,
#      'executions': 0.0,
#      'gulagKills': 0.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 2.0,
#      'percentTimeMoving': 86.02151,
#      'miscXp': 0.0,
#      'longestStreak': 1.0,
#      'teamPlacement': 30.0,
#      'damageDone': 212.0,
#      'damageTaken': 200.0},
#     'player': {'team': 'team_sixty_four',
#      'rank': 30.0,
#      'awards': {},
#      'username': 'fernando16dl',
#      'uno': '14859775631267647860',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sm_t9heavy',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'holo',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_la_rpapa7',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_semtex',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 1.0,
#      'medalXp': 15.0,
#      'matchXp': 10780.0,
#      'scoreXp': 3575.0,
#      'wallBangs': 0.0,
#      'score': 3550.0,
#      'totalXp': 14370.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 26.0,
#      'scorePerMinute': 167.98107255520503,
#      'distanceTraveled': 299930.3,
#      'teamSurvivalTime': 1189824.0,
#      'deaths': 2.0,
#      'kdRatio': 0.5,
#      'bonusXp': 0.0,
#      'objectiveBrKioskBuy': 2.0,
#      'gulagDeaths': 0.0,
#      'timePlayed': 1268.0,
#      'executions': 0.0,
#      'gulagKills': 1.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 15.0,
#      'percentTimeMoving': 77.47069,
#      'miscXp': 0.0,
#      'longestStreak': 1.0,
#      'teamPlacement': 13.0,
#      'damageDone': 532.0,
#      'damageTaken': 483.0},
#     'player': {'team': 'team_sixty_one',
#      'rank': 26.0,
#      'awards': {},
#      'username': 'Vheran',
#      'uno': '16044100637313738548',
#      'clantag': '^3DYOPP^7',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sn_kilo98',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'scope',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_pi_cpapa',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_frag',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 5.0,
#      'medalXp': 365.0,
#      'objectiveTeamWiped': 2.0,
#      'objectiveLastStandKill': 4.0,
#      'matchXp': 9607.0,
#      'scoreXp': 4650.0,
#      'wallBangs': 0.0,
#      'score': 4650.0,
#      'totalXp': 14699.0,
#      'headshots': 3.0,
#      'assists': 1.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 270.873786407767,
#      'distanceTraveled': 278977.66,
#      'teamSurvivalTime': 962736.0,
#      'deaths': 2.0,
#      'kdRatio': 2.5,
#      'objectiveDestroyedVehicleHeavy': 1.0,
#      'objectiveBrDownEnemyCircle1': 5.0,
#      'objectiveBrMissionPickupTablet': 1.0,
#      'bonusXp': 0.0,
#      'objectiveBrKioskBuy': 2.0,
#      'gulagDeaths': 0.0,
#      'timePlayed': 1030.0,
#      'executions': 0.0,
#      'gulagKills': 1.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 4.0,
#      'percentTimeMoving': 68.51465,
#      'miscXp': 0.0,
#      'longestStreak': 6.0,
#      'teamPlacement': 16.0,
#      'damageDone': 1595.0,
#      'damageTaken': 544.0},
#     'player': {'team': 'team_five',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'Cdub2343',
#      'uno': '585016294843024025',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sm_t9heavy',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'holo',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_la_rpapa7',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_semtex',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 1.0,
#      'medalXp': 40.0,
#      'matchXp': 3850.0,
#      'scoreXp': 1050.0,
#      'wallBangs': 0.0,
#      'score': 950.0,
#      'totalXp': 4940.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 114.4578313253012,
#      'distanceTraveled': 159176.2,
#      'teamSurvivalTime': 421968.0,
#      'deaths': 2.0,
#      'kdRatio': 0.5,
#      'objectiveBrMissionPickupTablet': 1.0,
#      'bonusXp': 0.0,
#      'gulagDeaths': 0.0,
#      'timePlayed': 498.0,
#      'executions': 0.0,
#      'gulagKills': 1.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 6.0,
#      'percentTimeMoving': 95.74468,
#      'miscXp': 0.0,
#      'longestStreak': 1.0,
#      'teamPlacement': 54.0,
#      'damageDone': 214.0,
#      'damageTaken': 218.0},
#     'player': {'team': 'team_twenty_three',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'Spready_N_Ready',
#      'uno': '12830336',
#      'clantag': '^3DCSKN^7',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sm_t9heavy',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'holo',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_la_rpapa7',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_semtex',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 0.0,
#      'medalXp': 0.0,
#      'matchXp': 4228.0,
#      'scoreXp': 950.0,
#      'wallBangs': 0.0,
#      'score': 450.0,
#      'totalXp': 5178.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 59.34065934065934,
#      'distanceTraveled': 197468.39,
#      'teamSurvivalTime': 445248.0,
#      'deaths': 3.0,
#      'kdRatio': 0.0,
#      'objectiveBrMissionPickupTablet': 1.0,
#      'bonusXp': 0.0,
#      'objectiveReviver': 1.0,
#      'gulagDeaths': 2.0,
#      'timePlayed': 455.0,
#      'executions': 0.0,
#      'gulagKills': 0.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 3.0,
#      'percentTimeMoving': 54.545456,
#      'miscXp': 0.0,
#      'longestStreak': 0.0,
#      'teamPlacement': 51.0,
#      'damageDone': 35.0,
#      'damageTaken': 744.0},
#     'player': {'team': 'team_seventy_nine',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'SagoNz',
#      'uno': '12036525097869900917',
#      'clantag': 'YT',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sn_kilo98',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'scope',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_pi_cpapa',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_frag',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}},
#       {'primaryWeapon': {'name': 'iw8_sn_crossbow',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_fists',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_snapshot_grenade',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_semtex',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 1.0,
#      'medalXp': 35.0,
#      'matchXp': 4731.0,
#      'scoreXp': 1225.0,
#      'wallBangs': 0.0,
#      'score': 1125.0,
#      'totalXp': 5991.0,
#      'headshots': 0.0,
#      'assists': 1.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 116.58031088082902,
#      'distanceTraveled': 265941.72,
#      'teamSurvivalTime': 500256.0,
#      'deaths': 2.0,
#      'kdRatio': 0.5,
#      'objectiveBrDownEnemyCircle1': 1.0,
#      'objectiveBrMissionPickupTablet': 1.0,
#      'bonusXp': 0.0,
#      'gulagDeaths': 0.0,
#      'timePlayed': 579.0,
#      'executions': 0.0,
#      'gulagKills': 1.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 7.0,
#      'percentTimeMoving': 90.55118,
#      'miscXp': 0.0,
#      'longestStreak': 1.0,
#      'teamPlacement': 48.0,
#      'damageDone': 396.0,
#      'damageTaken': 290.0},
#     'player': {'team': 'team_forty_nine',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'OJSimpson',
#      'uno': '16212735839054198195',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sm_t9heavy',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'holo',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_la_rpapa7',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_semtex',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 0.0,
#      'medalXp': 25.0,
#      'matchXp': 5432.0,
#      'scoreXp': 2750.0,
#      'wallBangs': 0.0,
#      'score': 2550.0,
#      'totalXp': 8207.0,
#      'headshots': 0.0,
#      'assists': 1.0,
#      'challengeXp': 0.0,
#      'rank': 39.0,
#      'scorePerMinute': 240.56603773584902,
#      'distanceTraveled': 347757.7,
#      'teamSurvivalTime': 556896.0,
#      'deaths': 2.0,
#      'kdRatio': 0.0,
#      'bonusXp': 0.0,
#      'objectiveBrKioskBuy': 1.0,
#      'gulagDeaths': 1.0,
#      'timePlayed': 636.0,
#      'executions': 0.0,
#      'gulagKills': 0.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 4.0,
#      'percentTimeMoving': 82.2898,
#      'miscXp': 0.0,
#      'objectiveTrophyDefense': 1.0,
#      'longestStreak': 0.0,
#      'teamPlacement': 43.0,
#      'damageDone': 251.0,
#      'damageTaken': 330.0},
#     'player': {'team': 'team_twenty_five',
#      'rank': 39.0,
#      'awards': {},
#      'username': 'H4iryV4gin4',
#      'uno': '3574848726359712425',
#      'clantag': '^3RGOD*^7',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sm_t9heavy',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'holo',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_la_rpapa7',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_semtex',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 1.0,
#      'medalXp': 0.0,
#      'matchXp': 5297.0,
#      'scoreXp': 4350.0,
#      'wallBangs': 0.0,
#      'score': 4050.0,
#      'totalXp': 9647.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 412.5636672325976,
#      'distanceTraveled': 370059.3,
#      'teamSurvivalTime': 547056.0,
#      'deaths': 2.0,
#      'kdRatio': 0.5,
#      'bonusXp': 0.0,
#      'objectiveBrKioskBuy': 2.0,
#      'gulagDeaths': 0.0,
#      'timePlayed': 589.0,
#      'executions': 0.0,
#      'gulagKills': 1.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 8.0,
#      'percentTimeMoving': 96.71533,
#      'miscXp': 0.0,
#      'longestStreak': 1.0,
#      'teamPlacement': 44.0,
#      'damageDone': 332.0,
#      'damageTaken': 200.0},
#     'player': {'team': 'team_seventy_eight',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'SrWachitoh',
#      'uno': '8962193742948677046',
#      'clantag': '^3MXTXG^7',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sn_kilo98',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'scope',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_pi_cpapa',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_frag',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 2.0,
#      'medalXp': 10.0,
#      'objectiveLastStandKill': 1.0,
#      'matchXp': 6394.0,
#      'scoreXp': 4975.0,
#      'wallBangs': 0.0,
#      'score': 4675.0,
#      'totalXp': 11429.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 414.32791728212703,
#      'distanceTraveled': 248271.86,
#      'teamSurvivalTime': 606624.0,
#      'deaths': 2.0,
#      'kdRatio': 1.0,
#      'objectiveBrDownEnemyCircle1': 1.0,
#      'bonusXp': 0.0,
#      'objectiveBrKioskBuy': 2.0,
#      'gulagDeaths': 1.0,
#      'timePlayed': 677.0,
#      'executions': 0.0,
#      'gulagKills': 0.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 11.0,
#      'percentTimeMoving': 95.15859,
#      'miscXp': 0.0,
#      'longestStreak': 1.0,
#      'teamPlacement': 35.0,
#      'damageDone': 555.0,
#      'damageTaken': 200.0},
#     'player': {'team': 'team_thirty_two',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'stiward',
#      'uno': '11924167466903289008',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sm_t9heavy',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'holo',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_la_rpapa7',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_semtex',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 0.0,
#      'medalXp': 0.0,
#      'matchXp': 6931.0,
#      'scoreXp': 0.0,
#      'wallBangs': 0.0,
#      'score': 0.0,
#      'totalXp': 6931.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 0.0,
#      'distanceTraveled': 235439.22,
#      'teamSurvivalTime': 646032.0,
#      'deaths': 4.0,
#      'kdRatio': 0.0,
#      'bonusXp': 0.0,
#      'gulagDeaths': 3.0,
#      'timePlayed': 721.0,
#      'executions': 0.0,
#      'gulagKills': 0.0,
#      'nearmisses': 0.0,
#      'percentTimeMoving': 40.561623,
#      'miscXp': 0.0,
#      'longestStreak': 0.0,
#      'teamPlacement': 31.0,
#      'damageDone': 194.0,
#      'damageTaken': 813.0},
#     'player': {'team': 'team_twenty_six',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'PhantomPlayer52',
#      'uno': '17126172632098811572',
#      'clantag': '^3o---B^7',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_ar_kilo433',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'reflex2',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_sh_charlie725',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_twoprimaries',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_molotov',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}},
#       {'primaryWeapon': {'name': 'iw8_sn_crossbow',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_fists',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_snapshot_grenade',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_semtex',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}},
#       {'primaryWeapon': {'name': 'iw8_pi_golf21',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_fists',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'none',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'none',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 0.0,
#      'medalXp': 0.0,
# ...
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 1.0,
#      'medalXp': 20.0,
#      'objectiveLastStandKill': 1.0,
#      'matchXp': 6777.0,
#      'scoreXp': 1150.0,
#      'wallBangs': 0.0,
#      'score': 1125.0,
#      'totalXp': 8004.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 96.01706970128022,
#      'distanceTraveled': 350099.94,
#      'teamSurvivalTime': 631152.0,
#      'deaths': 2.0,
#      'kdRatio': 0.5,
#      'bonusXp': 0.0,
#      'gulagDeaths': 0.0,
#      'timePlayed': 703.0,
#      'executions': 0.0,
#      'gulagKills': 1.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 6.0,
#      'percentTimeMoving': 96.0,
#      'miscXp': 0.0,
#      'longestStreak': 2.0,
#      'teamPlacement': 32.0,
#      'damageDone': 337.0,
#      'damageTaken': 458.0},
#     'player': {'team': 'team_eleven',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'Sombra',
#      'uno': '9641338918658506429',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sm_t9heavy',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'holo',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_la_rpapa7',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_semtex',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 2.0,
#      'medalXp': 55.0,
#      'objectiveLastStandKill': 2.0,
#      'matchXp': 6498.0,
#      'scoreXp': 1000.0,
#      'wallBangs': 0.0,
#      'score': 1000.0,
#      'totalXp': 7609.0,
#      'headshots': 1.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 87.97653958944282,
#      'distanceTraveled': 388523.1,
#      'teamSurvivalTime': 608832.0,
#      'deaths': 2.0,
#      'kdRatio': 1.0,
#      'objectiveBrDownEnemyCircle1': 2.0,
#      'bonusXp': 0.0,
#      'gulagDeaths': 0.0,
#      'timePlayed': 682.0,
#      'executions': 0.0,
#      'gulagKills': 1.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 1.0,
#      'percentTimeMoving': 93.95425,
#      'miscXp': 0.0,
#      'longestStreak': 2.0,
#      'teamPlacement': 34.0,
#      'damageDone': 1068.0,
#      'damageTaken': 588.0},
#     'player': {'team': 'team_forty_two',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'Tomatekun7u7',
#      'uno': '2848575627005396408',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sn_kilo98',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'scope',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_pi_cpapa',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_frag',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 3.0,
#      'medalXp': 10.0,
#      'objectiveTeamWiped': 1.0,
#      'matchXp': 8431.0,
#      'scoreXp': 7450.0,
#      'wallBangs': 0.0,
#      'score': 6450.0,
#      'totalXp': 15993.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 54.0,
#      'scorePerMinute': 439.2735527809308,
#      'distanceTraveled': 438139.66,
#      'teamSurvivalTime': 808944.0,
#      'deaths': 2.0,
#      'kdRatio': 1.5,
#      'objectiveBrDownEnemyCircle1': 3.0,
#      'objectiveBrMissionPickupTablet': 1.0,
#      'bonusXp': 0.0,
#      'objectiveBrKioskBuy': 5.0,
#      'gulagDeaths': 0.0,
#      'timePlayed': 881.0,
#      'executions': 0.0,
#      'gulagKills': 1.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 8.0,
#      'percentTimeMoving': 96.05912,
#      'miscXp': 0.0,
#      'longestStreak': 1.0,
#      'teamPlacement': 22.0,
#      'damageDone': 855.0,
#      'damageTaken': 491.0},
#     'player': {'team': 'team_ten',
#      'rank': 54.0,
#      'awards': {},
#      'username': 'TGRBZULU',
#      'uno': '17172962819270970319',
#      'clantag': ' >:|~',
#      'brMissionStats': {'missionsComplete': 1,
#       'totalMissionXpEarned': 700.0,
#       'totalMissionWeaponXpEarned': 420.0,
#       'missionStatsByType': {'scavenger': {'weaponXp': 420.0,
#         'xp': 700.0,
#         'count': 1.0}}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sn_kilo98',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'scope',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_pi_cpapa',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_frag',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False},
#    {'utcStartSeconds': 1609796483,
#     'utcEndSeconds': 1609798050,
#     'map': 'mp_don3',
#     'mode': 'br_brduos',
#     'matchID': '13368494592966401607',
#     'duration': 1567000,
#     'playlistName': None,
#     'version': 1,
#     'gameType': 'wz',
#     'playerCount': 151,
#     'playerStats': {'kills': 1.0,
#      'medalXp': 20.0,
#      'matchXp': 6153.0,
#      'scoreXp': 1100.0,
#      'wallBangs': 0.0,
#      'score': 900.0,
#      'totalXp': 7273.0,
#      'headshots': 0.0,
#      'assists': 0.0,
#      'challengeXp': 0.0,
#      'rank': 27.0,
#      'scorePerMinute': 78.48837209302326,
#      'distanceTraveled': 328642.7,
#      'teamSurvivalTime': 594240.0,
#      'deaths': 2.0,
#      'kdRatio': 0.5,
#      'objectiveBrDownEnemyCircle1': 1.0,
#      'bonusXp': 0.0,
#      'gulagDeaths': 0.0,
#      'timePlayed': 688.0,
#      'executions': 0.0,
#      'gulagKills': 1.0,
#      'nearmisses': 0.0,
#      'objectiveBrCacheOpen': 6.0,
#      'percentTimeMoving': 74.55429,
#      'miscXp': 0.0,
#      'longestStreak': 1.0,
#      'teamPlacement': 37.0,
#      'damageDone': 599.0,
#      'damageTaken': 385.0},
#     'player': {'team': 'team_sixty_six',
#      'rank': 27.0,
#      'awards': {},
#      'username': 'AykAyEK-_-',
#      'uno': '74990419954240435',
#      'clantag': '-_-',
#      'brMissionStats': {'missionsComplete': 0,
#       'totalMissionXpEarned': 0.0,
#       'totalMissionWeaponXpEarned': 0.0,
#       'missionStatsByType': {}},
#      'loadout': [{'primaryWeapon': {'name': 'iw8_sn_kilo98',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'scope',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'secondaryWeapon': {'name': 'iw8_pi_cpapa',
#         'label': None,
#         'imageLoot': None,
#         'imageIcon': None,
#         'variant': '-1',
#         'attachments': [{'name': 'none',
#           'label': None,
#           'image': None,
#           'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None},
#          {'name': 'none', 'label': None, 'image': None, 'category': None}]},
#        'perks': [{'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'specialty_null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'extraPerks': [{'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None},
#         {'name': 'null',
#          'label': None,
#          'image': None,
#          'imageMainUi': None,
#          'imageProgression': None}],
#        'killstreaks': [{'name': 'none', 'label': None},
#         {'name': 'none', 'label': None},
#         {'name': 'none', 'label': None}],
#        'tactical': {'name': 'equip_concussion',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None},
#        'lethal': {'name': 'equip_frag',
#         'label': None,
#         'image': None,
#         'imageLarge': None,
#         'progressionImage': None}}]},
#     'teamCount': 79,
#     'rankedTeams': None,
#     'draw': False,
#     'privateMatch': False}]}}

# %%
# all the matches are then concated into one single large dataframe 
# json_normalize flattens the nested dictionaries into a single dataframe (excluding player.loadout)
all_dfs = []
for i in tqdm.tqdm(range(len(duels))):
    try:
        all_dfs.append(pd.json_normalize(duels[i]['data']['allPlayers']))
    except:
        print(f'{i} is useless')
mega_df = pd.concat(all_dfs)
# Out:
#  50%|█████     | 505/1000 [01:36<00:53,  9.28it/s]
# 502 is useless
# 100%|██████████| 1000/1000 [02:55<00:00,  5.69it/s]

# %%
mega_df.to_csv('../../mega_df.csv')

# %%
mega_df.shape
# Out:
# (149009, 157)
